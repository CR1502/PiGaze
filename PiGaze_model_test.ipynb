# %%
import os
import dlib
import cv2
import numpy as np
import torch
import torch.nn as nn

# %%
class EyeTrackingModel(nn.Module):
    def __init__(self):
        super(EyeTrackingModel, self).__init__()
        self.fc_landmarks = nn.Sequential(
            nn.Linear(136, 256),
            nn.ReLU(),
            nn.Linear(256, 128)
        )
        self.fc_combined = nn.Sequential(
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 2)  # Predict gaze point (x, y)
        )

    def forward(self, landmarks):
        x = self.fc_landmarks(landmarks)
        return self.fc_combined(x)

# %%
# Device Configuration
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")

# Load the Model
model = EyeTrackingModel().to(device)
model.load_state_dict(torch.load("model_9.pth", map_location=device))
model.eval()
print("Model loaded successfully.")
# Out:
# Using device: mps
# Model loaded successfully.
# /var/folders/71/ybd134t50bl9zh8hzq85874r0000gn/T/ipykernel_17929/3324036227.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("model_9.pth", map_location=device))

# %%
# Initialize Dlib's Face Detector and Shape Predictor
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")

# %%
def map_direction(gaze_x, gaze_y):
    """
    Maps gaze coordinates to a direction (e.g., "Left", "Right", "Up", "Down", "Center").
    """
    # Updated thresholds for "Center"
    center_x_min, center_x_max = 0.40, 0.45
    center_y_min, center_y_max = 0.40, 0.45

    # Debugging: Print gaze predictions
    print(f"Mapping Gaze: x={gaze_x:.4f}, y={gaze_y:.4f}")

    # Check for "Center"
    if center_x_min <= gaze_x <= center_x_max and center_y_min <= gaze_y <= center_y_max:
        print("Direction: Center")
        return "Center"

    # Map to other directions
    if gaze_x < center_x_min:
        print("Direction: Left")
        return "Left"
    elif gaze_x > center_x_max:
        print("Direction: Right")
        return "Right"
    elif gaze_y < center_y_min:
        print("Direction: Up")
        return "Up"
    elif gaze_y > center_y_max:
        print("Direction: Down")
        return "Down"

    print("Direction: Undefined")
    return "Undefined"  # Fallback case

# %%
def test_live_feed():
    """
    Tests the model using a live camera feed to predict and display gaze direction.
    """
    cap = cv2.VideoCapture(0)
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

    if not cap.isOpened():
        print("Failed to open camera.")
        return

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Flip the camera feed for a mirrored view
        frame = cv2.flip(frame, 1)

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = detector(gray)

        if len(faces) > 0:
            for face in faces:
                # Extract landmarks
                landmarks = predictor(gray, face)
                landmark_coords = np.array([[p.x, p.y] for p in landmarks.parts()], dtype=np.float32).flatten()

                # Predict gaze
                input_tensor = torch.tensor(landmark_coords, dtype=torch.float32).unsqueeze(0).to(device)
                with torch.no_grad():
                    gaze = model(input_tensor).cpu().numpy()[0]

                # Debugging: Print gaze prediction
                print(f"Gaze Prediction (x, y): ({gaze[0]:.2f}, {gaze[1]:.2f})")

                # Map gaze to direction
                direction = map_direction(gaze[0], gaze[1])

                # Display the direction on the frame
                cv2.putText(frame, f"Direction: {direction}", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

                # Draw landmarks for debugging
                for point in landmarks.parts():
                    x, y = point.x, point.y
                    cv2.circle(frame, (x, y), 1, (255, 0, 0), -1)

        else:
            # If no face detected
            cv2.putText(frame, "No face detected", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

        # Display the frame
        cv2.imshow("Live Gaze Tracking", frame)

        # Exit on 'q' key
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    cap.release()
    cv2.destroyAllWindows()

# %%
# Run the Live Test
test_live_feed()
# Out:
# Gaze Prediction (x, y): (0.55, 0.37)
# Mapping Gaze: x=0.5457, y=0.3694
# Direction: Right
# Gaze Prediction (x, y): (0.54, 0.37)
# Mapping Gaze: x=0.5420, y=0.3661
# Direction: Right
# Gaze Prediction (x, y): (0.55, 0.38)
# Mapping Gaze: x=0.5466, y=0.3806
# Direction: Right
# Gaze Prediction (x, y): (0.54, 0.37)
# Mapping Gaze: x=0.5414, y=0.3687
# Direction: Right
# Gaze Prediction (x, y): (0.54, 0.36)
# Mapping Gaze: x=0.5439, y=0.3645
# Direction: Right
# Gaze Prediction (x, y): (0.54, 0.36)
# Mapping Gaze: x=0.5404, y=0.3598
# Direction: Right
# Gaze Prediction (x, y): (0.52, 0.40)
# Mapping Gaze: x=0.5240, y=0.3977
# Direction: Right
# Gaze Prediction (x, y): (0.50, 0.41)
# Mapping Gaze: x=0.4955, y=0.4080
# Direction: Right
# Gaze Prediction (x, y): (0.48, 0.41)
# Mapping Gaze: x=0.4813, y=0.4131
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.40)
# Mapping Gaze: x=0.4614, y=0.3957
# Direction: Right
# 2024-11-30 12:58:24.746 python[17929:1591672] +[IMKClient subclass]: chose IMKClient_Modern
# 2024-11-30 12:58:24.746 python[17929:1591672] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4371, y=0.3863
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.38)
# Mapping Gaze: x=0.4378, y=0.3788
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.39)
# Mapping Gaze: x=0.4347, y=0.3891
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.39)
# Mapping Gaze: x=0.4326, y=0.3915
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.40)
# Mapping Gaze: x=0.4370, y=0.3973
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.40)
# Mapping Gaze: x=0.4409, y=0.4026
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.40)
# Mapping Gaze: x=0.4418, y=0.4037
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.40)
# Mapping Gaze: x=0.4423, y=0.4032
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.40)
# Mapping Gaze: x=0.4440, y=0.4031
# Direction: Center
# Gaze Prediction (x, y): (0.45, 0.40)
# Mapping Gaze: x=0.4451, y=0.4027
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.40)
# Mapping Gaze: x=0.4443, y=0.4042
# Direction: Center
# Gaze Prediction (x, y): (0.45, 0.40)
# Mapping Gaze: x=0.4457, y=0.4040
# Direction: Center
# Gaze Prediction (x, y): (0.45, 0.40)
# Mapping Gaze: x=0.4453, y=0.4011
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.40)
# Mapping Gaze: x=0.4449, y=0.4036
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.40)
# Mapping Gaze: x=0.4448, y=0.4019
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.40)
# Mapping Gaze: x=0.4447, y=0.4030
# Direction: Center
# Gaze Prediction (x, y): (0.45, 0.40)
# Mapping Gaze: x=0.4458, y=0.4017
# Direction: Center
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4457, y=0.4051
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4445, y=0.4077
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4447, y=0.4055
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4442, y=0.4076
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4441, y=0.4066
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4439, y=0.4079
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4440, y=0.4072
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4439, y=0.4088
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4429, y=0.4086
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4438, y=0.4077
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4441, y=0.4050
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4437, y=0.4088
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4433, y=0.4061
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4430, y=0.4084
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4426, y=0.4089
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4432, y=0.4083
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4437, y=0.4081
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4434, y=0.4095
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4429, y=0.4108
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4426, y=0.4116
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4429, y=0.4104
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4428, y=0.4119
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4430, y=0.4120
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4429, y=0.4117
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4427, y=0.4122
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4428, y=0.4106
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4426, y=0.4128
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4429, y=0.4136
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4431, y=0.4137
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4436, y=0.4102
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4439, y=0.4094
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.41)
# Mapping Gaze: x=0.4438, y=0.4103
# Direction: Center
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4457, y=0.4077
# Direction: Center
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4453, y=0.4053
# Direction: Center
# Gaze Prediction (x, y): (0.45, 0.40)
# Mapping Gaze: x=0.4461, y=0.4030
# Direction: Center
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4456, y=0.4058
# Direction: Center
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4486, y=0.4084
# Direction: Center
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4503, y=0.4058
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4501, y=0.4080
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4501, y=0.4095
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4508, y=0.4091
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4502, y=0.4080
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4506, y=0.4093
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4505, y=0.4082
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4501, y=0.4081
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4492, y=0.4083
# Direction: Center
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4498, y=0.4086
# Direction: Center
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4503, y=0.4089
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4505, y=0.4097
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4511, y=0.4089
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4513, y=0.4071
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4503, y=0.4087
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4507, y=0.4091
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4501, y=0.4079
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4508, y=0.4073
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4513, y=0.4060
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4506, y=0.4058
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4503, y=0.4069
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4506, y=0.4065
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4517, y=0.4066
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4503, y=0.4072
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.40)
# Mapping Gaze: x=0.4510, y=0.4050
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4509, y=0.4062
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4514, y=0.4051
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4512, y=0.4060
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4519, y=0.4051
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4513, y=0.4054
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.40)
# Mapping Gaze: x=0.
# Direction: Up
# Gaze Prediction (x, y): (0.45, 0.37)
# Mapping Gaze: x=0.4483, y=0.3725
# Direction: Up
# Gaze Prediction (x, y): (0.45, 0.37)
# Mapping Gaze: x=0.4499, y=0.3695
# Direction: Up
# Gaze Prediction (x, y): (0.45, 0.38)
# Mapping Gaze: x=0.4470, y=0.3751
# Direction: Up
# Gaze Prediction (x, y): (0.45, 0.37)
# Mapping Gaze: x=0.4532, y=0.3711
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.38)
# Mapping Gaze: x=0.4512, y=0.3775
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.38)
# Mapping Gaze: x=0.4533, y=0.3791
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.38)
# Mapping Gaze: x=0.4607, y=0.3784
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.37)
# Mapping Gaze: x=0.4618, y=0.3720
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.37)
# Mapping Gaze: x=0.4640, y=0.3731
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.36)
# Mapping Gaze: x=0.4555, y=0.3631
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.35)
# Mapping Gaze: x=0.4585, y=0.3545
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.36)
# Mapping Gaze: x=0.4514, y=0.3612
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.36)
# Mapping Gaze: x=0.4484, y=0.3562
# Direction: Up
# Gaze Prediction (x, y): (0.45, 0.35)
# Mapping Gaze: x=0.4517, y=0.3499
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.34)
# Mapping Gaze: x=0.4567, y=0.3434
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.32)
# Mapping Gaze: x=0.4580, y=0.3236
# Direction: Right
# Gaze Prediction (x, y): (0.44, 0.32)
# Mapping Gaze: x=0.4417, y=0.3223
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.31)
# Mapping Gaze: x=0.4227, y=0.3109
# Direction: Up
# Gaze Prediction (x, y): (0.40, 0.30)
# Mapping Gaze: x=0.3952, y=0.2971
# Direction: Left
# Gaze Prediction (x, y): (0.40, 0.30)
# Mapping Gaze: x=0.3954, y=0.3025
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.30)
# Mapping Gaze: x=0.3931, y=0.2983
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.30)
# Mapping Gaze: x=0.3883, y=0.3033
# Direction: Left
# Gaze Prediction (x, y): (0.37, 0.29)
# Mapping Gaze: x=0.3722, y=0.2899
# Direction: Left
# Gaze Prediction (x, y): (0.35, 0.29)
# Mapping Gaze: x=0.3535, y=0.2923
# Direction: Left
# Gaze Prediction (x, y): (0.36, 0.29)
# Mapping Gaze: x=0.3574, y=0.2943
# Direction: Left
# Gaze Prediction (x, y): (0.37, 0.30)
# Mapping Gaze: x=0.3742, y=0.3012
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.30)
# Mapping Gaze: x=0.3859, y=0.3004
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.30)
# Mapping Gaze: x=0.3897, y=0.3048
# Direction: Left
# Gaze Prediction (x, y): (0.40, 0.31)
# Mapping Gaze: x=0.3951, y=0.3069
# Direction: Left
# Gaze Prediction (x, y): (0.41, 0.30)
# Mapping Gaze: x=0.4089, y=0.2990
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.32)
# Mapping Gaze: x=0.4409, y=0.3172
# Direction: Up
# Gaze Prediction (x, y): (0.45, 0.32)
# Mapping Gaze: x=0.4456, y=0.3225
# Direction: Up
# Gaze Prediction (x, y): (0.45, 0.33)
# Mapping Gaze: x=0.4480, y=0.3311
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.34)
# Mapping Gaze: x=0.4449, y=0.3411
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.36)
# Mapping Gaze: x=0.4364, y=0.3552
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.35)
# Mapping Gaze: x=0.4442, y=0.3469
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.34)
# Mapping Gaze: x=0.4419, y=0.3423
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.35)
# Mapping Gaze: x=0.4441, y=0.3473
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.34)
# Mapping Gaze: x=0.4434, y=0.3421
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.35)
# Mapping Gaze: x=0.4412, y=0.3485
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.36)
# Mapping Gaze: x=0.4380, y=0.3602
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.35)
# Mapping Gaze: x=0.4312, y=0.3530
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.35)
# Mapping Gaze: x=0.4301, y=0.3509
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.35)
# Mapping Gaze: x=0.4274, y=0.3519
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.35)
# Mapping Gaze: x=0.4256, y=0.3498
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.36)
# Mapping Gaze: x=0.4202, y=0.3650
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.38)
# Mapping Gaze: x=0.4243, y=0.3774
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.39)
# Mapping Gaze: x=0.4317, y=0.3861
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.39)
# Mapping Gaze: x=0.4262, y=0.3921
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.40)
# Mapping Gaze: x=0.4219, y=0.3960
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.39)
# Mapping Gaze: x=0.4207, y=0.3935
# Direction: Up
# Gaze Prediction (x, y): (0.41, 0.40)
# Mapping Gaze: x=0.4134, y=0.3953
# Direction: Up
# Gaze Prediction (x, y): (0.41, 0.40)
# Mapping Gaze: x=0.4097, y=0.4048
# Direction: Center
# Gaze Prediction (x, y): (0.40, 0.41)
# Mapping Gaze: x=0.4040, y=0.4085
# Direction: Center
# Gaze Prediction (x, y): (0.41, 0.40)
# Mapping Gaze: x=0.4052, y=0.4046
# Direction: Center
# Gaze Prediction (x, y): (0.40, 0.41)
# Mapping Gaze: x=0.3990, y=0.4101
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.42)
# Mapping Gaze: x=0.3942, y=0.4169
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.42)
# Mapping Gaze: x=0.3921, y=0.4208
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.42)
# Mapping Gaze: x=0.3932, y=0.4245
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.42)
# Mapping Gaze: x=0.3947, y=0.4241
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3901, y=0.4296
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3922, y=0.4255
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3871, y=0.4272
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3878, y=0.4274
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3878, y=0.4305
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3896, y=0.4298
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3903, y=0.4290
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3896, y=0.4283
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3899, y=0.4285
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3897, y=0.4266
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.42)
# Mapping Gaze: x=0.3896, y=0.4238
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3901, y=0.4256
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3908, y=0.4257
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.42)
# Mapping Gaze: x=0.3905, y=0.4241
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.42)
# Mapping Gaze: x=0.3914, y=0.4230
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.42)
# Mapping Gaze: x=0.3911, y=0.4229
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3894, y=0.4269
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3911, y=0.4254
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.42)
# Mapping Gaze: x=0.3903, y=0.4248
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3906, y=0.4263
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3915, y=0.4258
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3897, y=0.4281
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3902, y=0.4265
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3902, y=0.4258
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3896, y=0.4269
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.42)
# Mapping Gaze: x=0.3906, y=0.4246
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.42)
# Mapping Gaze: x=0.3915, y=0.4246
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3920, y=0.4287
# Direction: Left
# Gaze Prediction (x, y): (0.39, 0.43)
# Mapping Gaze: x=0.3921, y=0.4275
# Direction: Left
# Gaze Prediction (x, y): (0.40, 0.42)
# Mapping Gaze: x=0.3969, y=0.4227
# Direction: Left
# Gaze Prediction (x, y): (0.40, 0.42)
# Mapping Gaze: x=0.3999, y=0.4224
# Direction: Left
# Gaze Prediction (x, y): (0.40, 0.42)
# Mapping Gaze: x=0.4008, y=0.4240
# Direction: Center
# Gaze Prediction (x, y): (0.41, 0.42)
# Mapping Gaze: x=0.4063, y=0.4214
# Direction: Center
# Gaze Prediction (x, y): (0.41, 0.42)
# Mapping Gaze: x=0.4088, y=0.4208
# Direction: Center
# Gaze Prediction (x, y): (0.41, 0.42)
# Mapping Gaze: x=0.4137, y=0.4178
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4155, y=0.4175
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4191, y=0.4160
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.41)
# Mapping Gaze: x=0.4213, y=0.4108
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.41)
# Mapping Gaze: x=0.4251, y=0.4094
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.41)
# Mapping Gaze: x=0.4286, y=0.4056
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.40)
# Mapping Gaze: x=0.4299, y=0.4011
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.40)
# Mapping Gaze: x=0.4323, y=0.4000
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.40)
# Mapping Gaze: x=0.4326, y=0.3970
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4359, y=0.3913
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.39)
# Mapping Gaze: x=0.4343, y=0.3933
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4358, y=0.3920
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4368, y=0.3883
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4379, y=0.3865
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4395, y=0.3865
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4398, y=0.3859
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4399, y=0.3861
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4411, y=0.3855
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.38)
# Mapping Gaze: x=0.4415, y=0.3836
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4433, y=0.3898
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4427, y=0.3895
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4433, y=0.3883
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4427, y=0.3891
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4426, y=0.3904
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4446, y=0.3882
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4436, y=0.3890
# Direction: Up
# Gaze Prediction (x, y): (0.45, 0.39)
# Mapping Gaze: x=0.4450, y=0.3902
# Direction: Up
# Gaze Prediction (x, y): (0.45, 0.39)
# Mapping Gaze: x=0.4456, y=0.3923
# Direction: Up
# Gaze Prediction (x, y): (0.45, 0.39)
# Mapping Gaze: x=0.4464, y=0.3942
# Direction: Up
# Gaze Prediction (x, y): (0.45, 0.40)
# Mapping Gaze: x=0.4454, y=0.3961
# Direction: Up
# Gaze Prediction (x, y): (0.45, 0.40)
# Mapping Gaze: x=0.4467, y=0.3969
# Direction: Up
# Gaze Prediction (x, y): (0.45, 0.40)
# Mapping Gaze: x=0.4461, y=0.3984
# Direction: Up
# Gaze Prediction (x, y): (0.45, 0.40)
# Mapping Gaze: x=0.4467, y=0.3981
# Direction: Up
# Gaze Prediction (x, y): (0.45, 0.40)
# Mapping Gaze: x=0.4488, y=0.3980
# Direction: Up
# Gaze Prediction (x, y): (0.45, 0.40)
# Mapping Gaze: x=0.4478, y=0.3997
# Direction: Up
# Gaze Prediction (x, y): (0.45, 0.40)
# Mapping Gaze: x=0.
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4168, y=0.4202
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4158, y=0.4236
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4169, y=0.4209
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4174, y=0.4219
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4206, y=0.4185
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4178, y=0.4216
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4175, y=0.4201
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4182, y=0.4218
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4150, y=0.4244
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4174, y=0.4219
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4157, y=0.4221
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4183, y=0.4215
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4172, y=0.4229
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4179, y=0.4226
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4162, y=0.4228
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4151, y=0.4221
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4169, y=0.4216
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4167, y=0.4212
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4158, y=0.4212
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4150, y=0.4240
# Direction: Center
# Gaze Prediction (x, y): (0.41, 0.43)
# Mapping Gaze: x=0.4148, y=0.4257
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4171, y=0.4217
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4168, y=0.4223
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4180, y=0.4229
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4156, y=0.4233
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4162, y=0.4222
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4156, y=0.4223
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4175, y=0.4218
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4180, y=0.4203
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4174, y=0.4219
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4186, y=0.4213
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4181, y=0.4217
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4161, y=0.4224
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4179, y=0.4221
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4182, y=0.4202
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4211, y=0.4228
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4187, y=0.4225
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4178, y=0.4219
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4185, y=0.4228
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4173, y=0.4239
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.42)
# Mapping Gaze: x=0.4188, y=0.4184
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.41)
# Mapping Gaze: x=0.4264, y=0.4112
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.41)
# Mapping Gaze: x=0.4288, y=0.4087
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.42)
# Mapping Gaze: x=0.4310, y=0.4158
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.41)
# Mapping Gaze: x=0.4339, y=0.4138
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.42)
# Mapping Gaze: x=0.4332, y=0.4158
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.42)
# Mapping Gaze: x=0.4332, y=0.4160
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.41)
# Mapping Gaze: x=0.4326, y=0.4135
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.42)
# Mapping Gaze: x=0.4329, y=0.4157
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.42)
# Mapping Gaze: x=0.4325, y=0.4153
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.42)
# Mapping Gaze: x=0.4325, y=0.4159
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.42)
# Mapping Gaze: x=0.4316, y=0.4194
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.43)
# Mapping Gaze: x=0.4276, y=0.4272
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.43)
# Mapping Gaze: x=0.4275, y=0.4254
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.42)
# Mapping Gaze: x=0.4332, y=0.4187
# Direction: Center
# Gaze Prediction (x, y): (0.46, 0.35)
# Mapping Gaze: x=0.4573, y=0.3499
# Direction: Right
# Gaze Prediction (x, y): (0.33, 0.22)
# Mapping Gaze: x=0.3273, y=0.2178
# Direction: Left
# Gaze Prediction (x, y): (0.32, 0.26)
# Mapping Gaze: x=0.3239, y=0.2583
# Direction: Left
# Gaze Prediction (x, y): (0.37, 0.33)
# Mapping Gaze: x=0.3693, y=0.3328
# Direction: Left
# Gaze Prediction (x, y): (0.47, 0.36)
# Mapping Gaze: x=0.4693, y=0.3595
# Direction: Right
# Gaze Prediction (x, y): (0.48, 0.39)
# Mapping Gaze: x=0.4834, y=0.3936
# Direction: Right
# Gaze Prediction (x, y): (0.49, 0.39)
# Mapping Gaze: x=0.4933, y=0.3949
# Direction: Right
# Gaze Prediction (x, y): (0.48, 0.42)
# Mapping Gaze: x=0.4758, y=0.4179
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.39)
# Mapping Gaze: x=0.4519, y=0.3924
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.39)
# Mapping Gaze: x=0.4458, y=0.3887
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.39)
# Mapping Gaze: x=0.4295, y=0.3912
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.39)
# Mapping Gaze: x=0.4294, y=0.3931
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.40)
# Mapping Gaze: x=0.4262, y=0.3975
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.40)
# Mapping Gaze: x=0.4236, y=0.4001
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.40)
# Mapping Gaze: x=0.4229, y=0.4023
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.41)
# Mapping Gaze: x=0.4264, y=0.4077
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.41)
# Mapping Gaze: x=0.4311, y=0.4140
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.41)
# Mapping Gaze: x=0.4291, y=0.4129
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.43)
# Mapping Gaze: x=0.4363, y=0.4252
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.43)
# Mapping Gaze: x=0.4383, y=0.4299
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.43)
# Mapping Gaze: x=0.4428, y=0.4297
# Direction: Center
# Gaze Prediction (x, y): (0.45, 0.43)
# Mapping Gaze: x=0.4464, y=0.4277
# Direction: Center
# Gaze Prediction (x, y): (0.45, 0.42)
# Mapping Gaze: x=0.4487, y=0.4204
# Direction: Center
# Gaze Prediction (x, y): (0.45, 0.42)
# Mapping Gaze: x=0.4505, y=0.4212
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.42)
# Mapping Gaze: x=0.4511, y=0.4186
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.42)
# Mapping Gaze: x=0.4521, y=0.4170
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4563, y=0.4122
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4567, y=0.4124
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4567, y=0.4114
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4578, y=0.4098
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4584, y=0.4063
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4581, y=0.4081
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4583, y=0.4052
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4596, y=0.4080
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4601, y=0.4081
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4613, y=0.4114
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4615, y=0.4128
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4612, y=0.4119
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4615, y=0.4147
# Direction: Right
# Gaze Prediction (x, y): (0.47, 0.41)
# Mapping Gaze: x=0.4651, y=0.4080
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4644, y=0.4086
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4615, y=0.4101
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4614, y=0.4058
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.40)
# Mapping Gaze: x=0.4592, y=0.4038
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.40)
# Mapping Gaze: x=0.4613, y=0.4029
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4599, y=0.4059
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4581, y=0.4077
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4572, y=0.4092
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4575, y=0.4084
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4579, y=0.4094
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4563, y=0.4074
# Direction: Right
# Gaze Prediction (x, y): (0.46, 0.41)
# Mapping Gaze: x=0.4550, y=0.4103
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4549, y=0.4125
# Direction: Right
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4486, y=0.4070
# Direction: Center
# Gaze Prediction (x, y): (0.45, 0.41)
# Mapping Gaze: x=0.4482, y=0.4109
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.40)
# Mapping Gaze: x=0.4396, y=0.4022
# Direction: Center
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4399, y=0.3907
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.38)
# Mapping Gaze: x=0.4312, y=0.3843
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.38)
# Mapping Gaze: x=0.4259, y=0.3802
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.38)
# Mapping Gaze: x=0.4279, y=0.3785
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.38)
# Mapping Gaze: x=0.4336, y=0.3843
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.38)
# Mapping Gaze: x=0.4313, y=0.3837
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.38)
# Mapping Gaze: x=0.4382, y=0.3789
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.38)
# Mapping Gaze: x=0.4440, y=0.3814
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4430, y=0.3895
# Direction: Up
# Gaze Prediction (x, y): (0.45, 0.39)
# Mapping Gaze: x=0.4490, y=0.3937
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.40)
# Mapping Gaze: x=0.4432, y=0.3992
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.40)
# Mapping Gaze: x=0.4371, y=0.4025
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.40)
# Mapping Gaze: x=0.4334, y=0.4003
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.40)
# Mapping Gaze: x=0.4275, y=0.4033
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.40)
# Mapping Gaze: x=0.4237, y=0.4017
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.40)
# Mapping Gaze: x=0.4216, y=0.4012
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.40)
# Mapping Gaze: x=0.4197, y=0.4043
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.40)
# Mapping Gaze: x=0.4183, y=0.4044
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.40)
# Mapping Gaze: x=0.4208, y=0.3978
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.39)
# Mapping Gaze: x=0.4220, y=0.3942
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.38)
# Mapping Gaze: x=0.4230, y=0.3830
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.37)
# Mapping Gaze: x=0.4244, y=0.3682
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.37)
# Mapping Gaze: x=0.4236, y=0.3683
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.37)
# Mapping Gaze: x=0.4229, y=0.3663
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.37)
# Mapping Gaze: x=0.4232, y=0.3687
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.37)
# Mapping Gaze: x=0.4219, y=0.3673
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.36)
# Mapping Gaze: x=0.4204, y=0.3647
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.37)
# Mapping Gaze: x=0.4203, y=0.3700
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.37)
# Mapping Gaze: x=0.4177, y=0.3663
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.37)
# Mapping Gaze: x=0.4193, y=0.3694
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.37)
# Mapping Gaze: x=0.4196, y=0.3654
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.37)
# Mapping Gaze: x=0.4217, y=0.3701
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.37)
# Mapping Gaze: x=0.4215, y=0.3711
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.37)
# Mapping Gaze: x=0.4222, y=0.3725
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.37)
# Mapping Gaze: x=0.4225, y=0.3719
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.37)
# Mapping Gaze: x=0.4221, y=0.3718
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.37)
# Mapping Gaze: x=0.4218, y=0.3716
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.38)
# Mapping Gaze: x=0.4238, y=0.3780
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.38)
# Mapping Gaze: x=0.4246, y=0.3828
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.39)
# Mapping Gaze: x=0.4260, y=0.3858
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.39)
# Mapping Gaze: x=0.4288, y=0.3894
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.39)
# Mapping Gaze: x=0.4307, y=0.3932
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.40)
# Mapping Gaze: x=0.4299, y=0.3950
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.40)
# Mapping Gaze: x=0.4321, y=0.3951
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.40)
# Mapping Gaze: x=0.4326, y=0.3965
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.40)
# Mapping Gaze: x=0.4320, y=0.3964
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.40)
# Mapping Gaze: x=0.4319, y=0.3992
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.40)
# Mapping Gaze: x=0.4344, y=0.4017
# Direction: Center
# Gaze Prediction (x, y): (0.43, 0.40)
# Mapping Gaze: x=0.4339, y=0.3976
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.40)
# Mapping Gaze: x=0.4359, y=0.3958
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4386, y=0.3929
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4419, y=0.3897
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4433, y=0.3912
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4441, y=0.3920
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4431, y=0.3930
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4430, y=0.3930
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4417, y=0.3897
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.39)
# Mapping Gaze: x=0.4391, y=0.3897
# Direction: Up
# Gaze Prediction (x, y): (0.44, 0.38)
# Mapping Gaze: x=0.4375, y=0.3844
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.39)
# Mapping Gaze: x=0.4334, y=0.3880
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.39)
# Mapping Gaze: x=0.4252, y=0.3929
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.39)
# Mapping Gaze: x=0.4245, y=0.3947
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.39)
# Mapping Gaze: x=0.4337, y=0.3930
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.39)
# Mapping Gaze: x=0.4277, y=0.3884
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.37)
# Mapping Gaze: x=0.4220, y=0.3664
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.37)
# Mapping Gaze: x=0.4231, y=0.3710
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.40)
# Mapping Gaze: x=0.4249, y=0.3961
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.39)
# Mapping Gaze: x=0.4203, y=0.3871
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.40)
# Mapping Gaze: x=0.4261, y=0.4026
# Direction: Center
# Gaze Prediction (x, y): (0.42, 0.40)
# Mapping Gaze: x=0.4177, y=0.3976
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.39)
# Mapping Gaze: x=0.4231, y=0.3934
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.39)
# Mapping Gaze: x=0.4214, y=0.3899
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.41)
# Mapping Gaze: x=0.4207, y=0.4072
# Direction: Center
# Gaze Prediction (x, y): (0.41, 0.37)
# Mapping Gaze: x=0.4136, y=0.3719
# Direction: Up
# Gaze Prediction (x, y): (0.41, 0.37)
# Mapping Gaze: x=0.4125, y=0.3718
# Direction: Up
# Gaze Prediction (x, y): (0.41, 0.37)
# Mapping Gaze: x=0.4139, y=0.3742
# Direction: Up
# Gaze Prediction (x, y): (0.41, 0.37)
# Mapping Gaze: x=0.4127, y=0.3700
# Direction: Up
# Gaze Prediction (x, y): (0.41, 0.37)
# Mapping Gaze: x=0.4110, y=0.3691
# Direction: Up
# Gaze Prediction (x, y): (0.41, 0.37)
# Mapping Gaze: x=0.4111, y=0.3713
# Direction: Up
# Gaze Prediction (x, y): (0.41, 0.37)
# Mapping Gaze: x=0.4116, y=0.3658
# Direction: Up
# Gaze Prediction (x, y): (0.41, 0.38)
# Mapping Gaze: x=0.4113, y=0.3774
# Direction: Up
# Gaze Prediction (x, y): (0.41, 0.38)
# Mapping Gaze: x=0.4129, y=0.3823
# Direction: Up
# Gaze Prediction (x, y): (0.41, 0.38)
# Mapping Gaze: x=0.4134, y=0.3823
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.38)
# Mapping Gaze: x=0.4172, y=0.3799
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.38)
# Mapping Gaze: x=0.4174, y=0.3824
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.38)
# Mapping Gaze: x=0.4157, y=0.3832
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.39)
# Mapping Gaze: x=0.4163, y=0.3871
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.38)
# Mapping Gaze: x=0.4162, y=0.3831
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.39)
# Mapping Gaze: x=0.4162, y=0.3861
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.38)
# Mapping Gaze: x=0.4167, y=0.3835
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.38)
# Mapping Gaze: x=0.4167, y=0.3840
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.39)
# Mapping Gaze: x=0.4155, y=0.3911
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.38)
# Mapping Gaze: x=0.4164, y=0.3843
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.38)
# Mapping Gaze: x=0.4182, y=0.3822
# Direction: Up
# Gaze Prediction (x, y): (0.41, 0.35)
# Mapping Gaze: x=0.4143, y=0.3546
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.39)
# Mapping Gaze: x=0.4181, y=0.3938
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.39)
# Mapping Gaze: x=0.4174, y=0.3880
# Direction: Up
# Gaze Prediction (x, y): (0.41, 0.35)
# Mapping Gaze: x=0.4083, y=0.3517
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.39)
# Mapping Gaze: x=0.4195, y=0.3879
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.36)
# Mapping Gaze: x=0.4212, y=0.3553
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.36)
# Mapping Gaze: x=0.4264, y=0.3580
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.36)
# Mapping Gaze: x=0.4253, y=0.3553
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.36)
# Mapping Gaze: x=0.4263, y=0.3616
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.36)
# Mapping Gaze: x=0.4286, y=0.3621
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.36)
# Mapping Gaze: x=0.4292, y=0.3626
# Direction: Up
# Gaze Prediction (x, y): (0.43, 0.37)
# Mapping Gaze: x=0.4302, y=0.3673
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.36)
# Mapping Gaze: x=0.4220, y=0.3554
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.35)
# Mapping Gaze: x=0.4228, y=0.3493
# Direction: Up
# Gaze Prediction (x, y): (0.42, 0.35)
# Mapping Gaze: x=0.4200, y=0.3532
# Direction: Up
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Run the Live Test
# ----> 2 test_live_feed()
#
# Cell In[6], line 14, in test_live_feed()
#      11     return
#      13 while True:
# ---> 14     ret, frame = cap.read()
#      15     if not ret:
#      16         break
#
# KeyboardInterrupt:
